# %% [markdown]
# ## Goal: Build a classification model to categorize a user's gender.

# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/hotels.csv')
